# %%
import numpy as np
# %matplotlib notebook
import matplotlib.pyplot as plt

# %% [markdown]
# ### "Biology"

# %%
Npopulation = 10
Ngenes = 6
genes = np.asarray(['A', 'T', 'G', 'C'])
Pc = 0.80 #crossover probability
Pm = 0.05 #mutation probability

# %% [markdown]
# #### Generate initial population

# %%
def init_pop(Npopulation = 10, Ngenes = 6, genes = np.asarray(['A', 'T', 'G', 'C'])):
    return np.random.choice(genes, [Npopulation, Ngenes])

# %%
pop = init_pop()
print(pop)
# Out:
# [['G' 'T' 'G' 'G' 'C' 'C']
#  ['G' 'A' 'G' 'G' 'G' 'C']
#  ['C' 'T' 'G' 'G' 'G' 'C']
#  ['C' 'A' 'G' 'T' 'C' 'C']
#  ['A' 'G' 'G' 'C' 'C' 'A']
#  ['G' 'G' 'C' 'T' 'A' 'C']
#  ['C' 'A' 'T' 'C' 'C' 'T']
#  ['A' 'T' 'C' 'G' 'A' 'T']
#  ['A' 'G' 'G' 'G' 'A' 'G']
#  ['T' 'C' 'T' 'C' 'G' 'T']]

# %% [markdown]
# ### Evaluate

# %%
ideal = np.empty([Ngenes], dtype=pop.dtype )
ideal.fill('A')


def fitness(chromosome, ideal):
    test = chromosome == ideal
    return sum(test)

# %%
fitnessEval = np.asarray([fitness(i, ideal) for i in pop])
print(fitnessEval)
# Out:
# [0 1 0 1 2 1 1 2 2 0]

# %%
# choose two parents from max values (if more than 2 share max value, choose by random)

# %%
indices = np.asarray(np.where(fitnessEval == fitnessEval.max()))
indices.shape
# Out:
# (1, 3)

# %%
len(indices[0])
# Out:
# 3

# %% [markdown]
# ### Parents

# %%
def getParents(pop, ideal):
    fitnessEval = np.asarray([fitness(i, ideal) for i in pop])    
    indices = np.asarray(np.where(fitnessEval == fitnessEval.max()))
    parentID = np.empty([2], dtype='int')
    
    if len(indices[0]) > 2:
        parentID = np.random.choice(indices[0], [2], replace = False)
    elif (len(indices[0]) == 2):
        parentID = indices[0]
    else:
        parentID[0] = indices[0,0]
        fitnessEval2nd = np.delete(fitnessEval, parentID[0])
        indices2nd = np.delete(np.arange(len(fitnessEval)), parentID[0])
        indices2 = np.asarray(np.where(fitnessEval2nd == fitnessEval2nd.max()))
        if len(indices2[0]) == 1:
            parentID[1] = indices2nd[indices2[0]]
        else:
            parentID[1] = indices2nd[np.random.choice(indices2[0], [1], replace = False)]
        
    parent1 = pop[parentID[0],:]
    parent2 = pop[parentID[1],:]    
        
    return parent1, parent2

# %%
parent1, parent2 = getParents(pop, ideal)

# %%
print(parent1)
print(parent2)
# Out:
# ['A' 'G' 'G' 'G' 'A' 'G']
# ['A' 'T' 'C' 'G' 'A' 'T']

# %% [markdown]
# ### Crossover function

# %%
def crossover(parent1, parent2, Npopulation, Ngenes, Pc, elitist = True):
    pop = np.empty([Npopulation, Ngenes], dtype = 'U1')
    for i in range(Npopulation // 2 - (1 if elitist else 0)):
        crosses = np.random.random_sample(Ngenes) < Pc
        
        pop[2*i] = parent1
        pop[2*i+1] = parent2

        if crosses.any():
            pop[2*i,crosses] = parent2[crosses]
            pop[2*i+1,crosses] = parent1[crosses]
        
    if elitist:
        pop[Npopulation-2,:] = parent1
        pop[Npopulation-1,:] = parent2
        
    return pop

# %%
new_pop = crossover(parent1,parent2, 10, 6, 0.8)
print(new_pop)
# Out:
# [['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'A' 'A' 'A' 'T']
#  ['T' 'A' 'A' 'C' 'T' 'G']
#  ['G' 'A' 'A' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'A' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'A' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'A' 'A' 'T']
#  ['T' 'A' 'A' 'C' 'T' 'G']]

# %% [markdown]
# ### Mutate

# %%
def mutate(pop, genes, Pm = 0.05):
    for i, chromosome in enumerate(pop):
        for j, gene in enumerate(chromosome):
            if np.random.random() < Pm:
                pop[i,j] = np.random.choice(genes[np.where(genes != gene)]) 
    return pop

# %%
mut_pop = mutate(new_pop, genes)
print(mut_pop)
# Out:
# [['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'A' 'A' 'A' 'T']
#  ['T' 'A' 'G' 'C' 'T' 'G']
#  ['G' 'A' 'A' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'A' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'C' 'T' 'G']
#  ['T' 'A' 'C' 'A' 'A' 'T']
#  ['G' 'A' 'A' 'A' 'A' 'T']
#  ['T' 'A' 'A' 'C' 'T' 'G']]

# %% [markdown]
# ### Put together
# multiple generations

# %%
Npopulation = 10
Ngenes = 20
genes = np.asarray(['A', 'T', 'G', 'C'])
Pc = 0.80 #crossover probability
Pm = 0.05 #mutation probability

pop = init_pop(Npopulation = Npopulation, Ngenes = Ngenes)
ideal = np.empty([Ngenes], dtype=pop.dtype )
ideal.fill('A')

max_generations = 100

for i in range(max_generations):
    fitnessEval = np.asarray([fitness(i, ideal) for i in pop])
    print('Population fitness: {}'.format(np.mean(fitnessEval)))
    parent1, parent2 = getParents(pop, ideal)
    print('Generation {} parents: {}, {}'.format(i+1, parent1, parent2))
    new_pop = crossover(parent1,parent2, Npopulation, Ngenes, Pc)
    pop = mutate(new_pop, genes)
        
print('\n Final population:')
print(pop)
# Out:
# Population fitness: 3.5
# Generation 1 parents: ['A' 'A' 'C' 'T' 'T' 'G' 'T' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'T' 'G' 'G' 'A'
#  'C' 'C'], ['C' 'A' 'G' 'T' 'T' 'T' 'G' 'T' 'C' 'G' 'A' 'T' 'G' 'T' 'C' 'G' 'T' 'A'
#  'A' 'T']
# Population fitness: 4.8
# Generation 2 parents: ['A' 'A' 'C' 'T' 'C' 'T' 'G' 'C' 'C' 'C' 'A' 'T' 'A' 'A' 'T' 'G' 'C' 'A'
#  'G' 'C'], ['A' 'A' 'C' 'T' 'T' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'T' 'G' 'G' 'A'
#  'C' 'C']
# Population fitness: 6.1
# Generation 3 parents: ['A' 'A' 'C' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'T' 'G' 'G' 'A'
#  'G' 'C'], ['A' 'A' 'C' 'T' 'C' 'T' 'A' 'C' 'C' 'C' 'A' 'T' 'C' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 6.8
# Generation 4 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'T' 'G' 'T' 'A'
#  'G' 'C'], ['A' 'A' 'C' 'T' 'A' 'T' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'A' 'G' 'G' 'A'
#  'G' 'C']
# Population fitness: 7.8
# Generation 5 parents: ['A' 'A' 'C' 'T' 'A' 'T' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'G' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 7.5
# Generation 6 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'A' 'G' 'G' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'G' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 8.7
# Generation 7 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'G' 'T' 'C' 'C' 'A' 'C' 'A' 'A' 'A' 'G' 'G' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'G' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 8.3
# Generation 8 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'G' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'C' 'C' 'A' 'A' 'G' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 8.9
# Generation 9 parents: ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 9.7
# Generation 10 parents: ['A' 'A' 'A' 'G' 'A' 'G' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'T' 'T' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 9.6
# Generation 11 parents: ['A' 'A' 'A' 'G' 'A' 'G' 'T' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'T' 'T' 'A'
#  'G' 'C'], ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'C' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'G' 'C']
# Population fitness: 9.7
# Generation 12 parents: ['A' 'A' 'A' 'G' 'A' 'C' 'T' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'G' 'A' 'G' 'T' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'T' 'T' 'A'
#  'G' 'C']
# Population fitness: 11.3
# Generation 13 parents: ['A' 'A' 'A' 'G' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'G' 'G'], ['A' 'A' 'A' 'T' 'A' 'C' 'T' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'G' 'T' 'A'
#  'A' 'C']
# Population fitness: 12.2
# Generation 14 parents: ['A' 'A' 'A' 'G' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'G'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 13.7
# Generation 15 parents: ['A' 'A' 'A' 'C' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'G'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 12.8
# Generation 16 parents: ['A' 'A' 'A' 'C' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 13.7
# Generation 17 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 13.3
# Generation 18 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 14.1
# Generation 19 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 14.7
# Generation 20 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 14.7
# Generation 21 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'C'], ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A'
#  'A' 'C']
# Population fitness: 15.6
# Generation 22 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'C']
# Population fitness: 17.0
# Generation 23 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 16.9
# Generation 24 parents: ['A' 'A' 'A' 'T' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 16.9
# Generation 25 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.1
# Generation 26 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.1
# Generation 27 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.6
# Generation 28 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.6
# Generation 29 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.0
# Generation 30 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.1
# Generation 31 parents: ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'C' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.2
# Generation 32 parents: ['A' 'A' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.1
# Generation 33 parents: ['A' 'A' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.5
# Generation 34 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 35 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 36 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 37 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 38 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.1
# Generation 39 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.3
# Generation 40 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.8
# Generation 41 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 42 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 43 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 44 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 45 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 46 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.3
# Generation 47 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.7
# Generation 48 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.9
# Generation 49 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.3
# Generation 50 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.0
# Generation 51 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.6
# Generation 52 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.2
# Generation 53 parents: ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 54 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 55 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.2
# Generation 56 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.2
# Generation 57 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.7
# Generation 58 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.8
# Generation 59 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.0
# Generation 60 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.8
# Generation 61 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 62 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.6
# Generation 63 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.3
# Generation 64 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.4
# Generation 65 parents: ['A' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.1
# Generation 66 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.1
# Generation 67 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.5
# Generation 68 parents: ['A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 17.9
# Generation 69 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.0
# Generation 70 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.0
# Generation 71 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.4
# Generation 72 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.0
# Generation 73 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.5
# Generation 74 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.1
# Generation 75 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.8
# Generation 76 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.2
# Generation 77 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.6
# Generation 78 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.1
# Generation 79 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.6
# Generation 80 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'T' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.8
# Generation 81 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.4
# Generation 82 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 83 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.0
# Generation 84 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.7
# Generation 85 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 86 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.7
# Generation 87 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.3
# Generation 88 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.5
# Generation 89 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.3
# Generation 90 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.6
# Generation 91 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 92 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.8
# Generation 93 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.4
# Generation 94 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.5
# Generation 95 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 96 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.0
# Generation 97 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 98 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 19.5
# Generation 99 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
# Population fitness: 18.9
# Generation 100 parents: ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A'], ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#  'A' 'A']
#
#  Final population:
# [['C' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'C' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'C' 'A' 'A'
#   'A' 'A']
#  ['A' 'C' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'G' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'C' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']
#  ['A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A' 'A'
#   'A' 'A']]
